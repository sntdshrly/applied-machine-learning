# %% [markdown]
# # Pipeline

# %% [markdown]
# ![dos_1380771b1f47c1a3dcb668d3a0bd986c20210912101420.png](data:image/png;base64,...)

# %% [markdown]
# # Akuisisi Data

# %% [markdown]
# ## Menggunakan Data Publik

# %% [markdown]
# Bagi Anda yang telah lama berkecimpung di bidang data, tentu tidak asing lagi dengan situs penyedia data seperti Kaggle, UCI, mesin pencari dataset Google, maupun GitHub. Tahukan Anda? Selain sebagai tools version control dan ruang kolaborasi, para developer menggunakan GitHub untuk berbagi informasi mengenai berbagai sumber dataset untuk NLP. Contohnya adalah repository dari Nicolas Iderhoff dan IndoNLU.
#
# Selain itu, setiap layanan cloud seperti Google Cloud Service, Azure, maupun AWS juga menyediakan dataset publik yang bisa diakses oleh para penggunanya. Jika menemukan dataset publik yang relevan dan sesuai dengan pekerjaan yang sedang kita lakukan, gunakan dataset tersebut, buat modelnya, dan lakukan evaluasi.
#
# Permasalahannya, jika tidak menemukan data yang sesuai, apa yang bisa kita lakukan untuk mendapatkan data?

# %% [markdown]
# ## Mengumpulkan Data dari Internet (Web Scraping)

# %% [markdown]
# Internet merupakan sumber data yang melimpah. Web scraping adalah metode untuk memproses dan mengumpulkan data dari berbagai situs di internet. Dengan metode tersebut, Anda dapat mengekstrak konten dan informasi untuk analisis lebih lanjut.
#
# Para praktisi data biasanya melakukan proses scraping pada situs media sosial seperti twitter, wikipedia, bahkan e-commerce. Analisis data dari proses web scraping dapat digunakan untuk berbagai tujuan, antara lain: keperluan riset, memantau sentimen pasar, dan mendapatkan informasi mengenai kompetitor. Beberapa tools yang dapat digunakan untuk proses ini antara lain Beautifulsoup, Selenium, dan Scrapy.

# %% [markdown]
# ## Data Augmentation

# %% [markdown]
# Pada bidang computer vision, image augmentation adalah teknik standar yang sering digunakan. Sementara itu, pada NLP, text augmentation (augmentasi teks) masih jarang digunakan. Operasi pada gambar seperti proses memperbesar, membalik (flip) dan memutar (rotate) tidak mengubah gambar aslinya. Sehingga, proses transformasi melalui image augmentation merupakan teknik penting dalam bidang computer vision.
#
# Berbeda dengan computer vision, transformasi dengan text augmentation pada NLP menghadapi beberapa tantangan. Dua di antaranya adalah tantangan perubahan semantik (makna) dan tantangan kompleksitas bahasa yang tinggi seperti adanya konteks pembicaraan.
# ![dos_3991ef7353043a2a6d515ac29e6f47cb20220114115235.png](data:image/png;base64,...)

# %% [markdown]
# Meskipun demikian, terdapat beberapa pendekatan atau metode text augmentation yang bisa dilakukan untuk menghasilkan lebih banyak data. Disadur dari Chaudhary dalam tulisannya yang berjudul “Data Augmentation for NLP”, berikut adalah beberapa metode text augmentation:
#
# - Substitusi Leksikal (Lexical Substitution)
# Substitusi leksikal merupakan teknik yang bekerja dengan mengganti kata pada teks tanpa mengubah arti dalam kalimat. Teknik ini sendiri memiliki beberapa pendekatan, dua diantaranya adalah Thesaurus-based substitution (substitusi berdasarkan tesaurusnya) dan Word-Embeddings Substitution (substitusi dengan teknik word-embeddings). Jangan bingung dulu dengan istilah-istilah ini ya, mari kita bahas satu per satu.
#
# 1. Thesaurus-based substitution
# Dengan teknik ini, kita mengambil kata acak dari kalimat kemudian mengganti dengan sinonimnya menggunakan tesaurus. Sebagai contoh, untuk bahasa inggris, kita bisa menggunakan database WordNet dalam mencari sinonimnya, kemudian melakukan penggantian. WordNet merupakan database yang dikurasi secara manual dengan hubungan antar kata.
#
# ![dos_19113d1541715b8ab1df58346cf2225c20210912101723.png](data:image/png;base64,...)

# %% [markdown]
# 2. Word-Embeddings Substitution
# Dalam teknik ini, kita mengambil pre-trained word embeddings seperti Word2Vec, GloVe, FastText, Sent2Vec. Kemudian, kita menggunakan kata terdekat pada word embedding tersebut sebagai pengganti beberapa kata dalam kalimat.
# ![dos_d561f28839bb200d979bb4bd00d6c76920210912101755.png](data:image/png;base64,...)
#
# Sebagai contoh, kita bisa mengganti kata berikut dengan 3 kata yang paling mirip artinya untuk mendapatkan variasi pada teks.
# ![dos_8fd7a6a8c0b780989018908ee873461a20210912101829.png](data:image/png;base64,...)

# %% [markdown]
# - Back Translation
# Dalam teknik ini, kita menggunakan aplikasi mesin penerjemah untuk memparafrasakan teks sambil melatih kembali maknanya. Xie dkk menggunakan metode ini untuk menambah teks yang tidak berlabel dan mempelajari model semi-supervised pada dataset IMDB dengan hanya 20 contoh berlabel. Model mereka mengungguli model sebelumnya yang dilatih pada 25.000 contoh berlabel.
#
# Bayangkan, hanya dengan 20 contoh model berlabel mampu mengungguli 25.000 contoh berlabel. Luar biasa!
#
# Sampai di sini tentu Anda penasaran, seperti apa sih proses back-translation ini? Nah, tahapan proses back-translation adalah sebagai berikut:
#
# 1. Ambil beberapa kalimat (misalnya dalam bahasa Inggris) dan terjemahkan ke bahasa lain, misalnya Perancis
# 2. Terjemahkan kalimat bahasa Prancis menjadi kalimat bahasa Inggris kembali
# 3. Periksa apakah kalimat baru berbeda dari kalimat asli. Jika ya, maka kita akan menggunakan kalimat baru ini sebagai versi tambahan dari teks aslinya.
#
# ![dos_61392f39612039a60de4ede5f171c71a20210912101850.png](data:image/png;base64,...)

# %% [markdown]
# Anda juga dapat menjalankan terjemahan balik menggunakan beberapa bahasa yang berbeda sekaligus untuk menghasilkan lebih banyak variasi. Hal ini membuat prosesnya menjadi lebih efektif dan tentu saja dapat menekan sumber daya. Mari kita perhatikan contoh gambar di bawah.
#
# ![dos_2fc18d2e64bad297bb89abe6484cbfed20210912101920.png](data:image/png;base64,...)

# %% [markdown]
# # Text Cleaning dan Pre-processing

# %% [markdown]
# - Menghilangkan Noise (gangguan) pada Teks
# - Proses Tokenisasi
# - Proses Normalisasi

# %% [markdown]
# ## Menghilangkan Noise
# - Remove HTML Tag
# Teks tidak terstruktur biasanya mengandung banyak noise. Apalagi jika Anda menggunakan teknik seperti web scraping atau screen scraping untuk mengambil data dari halaman web. Tag HTML dan JavaScript biasanya tidak memiliki makna untuk proses analisis teks. Tujuan kita adalah mengekstrak konten tekstual yang bermakna dari data yang diambil dari web. Oleh karena itu, kita perlu melakukan proses penghapusan tag html.
#
# - Spelling Correction
# Siapa di sini yang masih melakukan kesalahan penulisan alias typo? Jangan khawatir, sebagian besar dari kita mungkin masih melakukan kesalahan semacam itu. Pengetikan cepat pada keyboard komputer maupun layar ponsel cerdas berpotensi memiliki kesalahan ejaan penulisan. Hal ini sangat lazim terjadi. Jika dibiarkan, ini bisa menjadi permasalahan yang dapat merusak pemahaman linguistik data.
#
# - Remove Stop Words
# Stop words adalah kata-kata yang memiliki sedikit makna pada teks. Biasanya, stop words ini berupa kata-kata yang paling sering muncul pada sekumpulan teks (corpus). Ia bisa berbentuk artikel, konjungsi, preposisi, dan sebagainya. Beberapa contoh stopword dalam bahasa inggris adalah a, an, is, and, dan the. Stop words harus dihapus sehingga algoritma machine learning dapat lebih fokus pada kata-kata yang memberikan makna dari teks. Kita bisa menggunakan daftar yang terdapat pada nltk.corpus packages untuk melakukan proses penghapusannya. Selain itu, kita juga bisa menambah atau menghapus kata-kata khusus menyesuaikan dengan proyek dan teks yang sedang kita kerjakan.
#
# - Remove Special Character
# Special character (karakter khusus) adalah karakter selain alfanumerik. Karakter ini paling sering ditemukan dalam referensi, komentar, nilai tukar mata uang, dsb. Karakter ini tidak menambah makna pada pemahaman teks sehingga dapat menyebabkan noise ke dalam algoritma. Untuk mengatasi dan menghilangkannya, kita bisa menggunakan regular expression atau regex.

# %% [markdown]
# ## Tokenisasi
# Berdasarkan dokumentasi NLTK (Natural Language Toolkit), terdapat beberapa teknik untuk melakukan tokenisasi kata, antara lain:
#
# - Word_tokenize
# - TreebankWordTokenizer
# - RegexpTokenizer
# ![dos_80d71a717f680537105587895e5a60c820210912102149.png](data:image/png;base64,...)

# %% [markdown]
# ## Normalisasi Teks
# ![dos_390069d72d474cc76ef251c6b7534d7e20210912102216.png](data:image/png;base64,...)
#
# - Mengubah semua teks menjadi huruf kecil atau huruf besar,
# - Mengonversi semua angka menjadi teks,
# - Mengeliminasi imbuhan,
# - Mengubah bentuk kata menjadi bentuk dasarnya.

# %% [markdown]
# ![dos_b1b4f012e1bb7b3a37b536de8fc3425920210921173507.png](data:image/png;base64,...)

# %% [markdown]
# ![dos_c316ee2ad09fb1ab0d9df66b30a817a920210912102320.png](data:image/png;base64,...)

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ![dos_479015e32d4c61586d911cd45eb83d2020210912102635.png](data:image/png;base64,...)

# %% [markdown]
# - Basic vectorization approaches (contoh: One-Hot Encoding, Bag of Words, Bag of N-Grams, dan TF-IDF).
# - Distributed representations (contoh: Words Embeddings).
# - Universal text representation (menggunakan pre-trained embedding).
# - Handcrafted features (mengandalkan domain-specific knowledge).

# %% [markdown]
# ## Bag of Words

# %% [markdown]
# Intuisi dasar di balik BoW adalah asumsi bahwa kelas tertentu dalam data memiliki ciri kumpulan kata yang unik. Jika dua potongan teks memiliki kata-kata yang hampir sama, mereka termasuk dalam tas (kelas) yang sama. Jadi, dengan menganalisis kata-kata yang ada dalam sepotong teks, seseorang dapat mengidentifikasi kelas (tas) yang dimilikinya.

# %% [markdown]
# ```
# Galih suka bermain basket.
# Ratna juga suka basket.
# Ratna suka menonton Galih bermain basket.
# ```

# %% [markdown]
# Jika kalimat di atas dihitung, kita memiliki 14 data kata. Tahap selanjutnya adalah membuat daftar kosa kata dalam data. Kata unik dalam data di atas (mengabaikan huruf besar dan tanda baca) adalah sebagai berikut:
#
# - “galih”
# - “suka”
# - “bermain”
# - “basket”
# - “ratna”
# - “juga”
# - “menonton”

# %% [markdown]
# ```
# “galih suka bermain basket” = [1, 1, 1, 1, 0, 0, 0]
# “ratna juga suka basket” = [0, 1, 0, 1, 1, 1, 0]
# “ratna suka menonton galih bermain basket" = [1, 1, 1, 1, 1, 0, 1]
# ```

# %% [markdown]
# Namun, teknik pemberian skor ini memiliki kekurangan. Kata-kata yang sangat sering muncul dalam dokumen mungkin tidak mengandung “konten informatif” terhadap model. Sedangkan, kata-kata yang jarang muncul justru mungkin mengandung makna penting dalam teks.

# %% [markdown]
# ## TF-IDF
# Nah, salah satu pendekatan untuk mengatasi kekurangan-kekurangan ini adalah dengan melakukan skala ulang terhadap frekuensi kata.

# %% [markdown]
# ### Term Frequency
# TF (Term Frequency) mengukur frekuensi atau seberapa sering suatu kata atau term muncul dalam teks tertentu. Teks yang berbeda dalam dokumen mungkin memiliki panjang yang berbeda, tergantung dari panjang dokumen. Oleh karena itu, kita melakukan normalisasi dengan membagi jumlah kemunculan terhadap panjang dokumen.
#
# ![202107291610325784de49f00104b077d2ccacea4d6ba5.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ### Inverse Document Frequency
# IDF (Inverse Document Frequency) mengukur pentingnya istilah di seluruh korpus. Dalam komputasi TF, semua istilah diberikan bobot kepentingan (weight) yang sama. Meskipun sering muncul, tentu Anda tahu bahwa stop word seperti is, are, am, dsb, tidaklah penting. Untuk mengatasi kasus seperti ini, IDF mempertimbangkan term yang sangat umum di seluruh dokumen dan menimbang istilah-istilah yang jarang.
# ![2021072916103253d5e45cb6d14c5e11c5642c468976bf.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ### Bobot
# Terakhir, untuk menghitung skor atau bobot untuk TF-IDF, kalikan nilai TF dengan IDF seperti di bawah ini:
# ![20210729161032371ea6d17d823e17c6967f0e74fb47f7.jpeg](data:image/jpeg;base64,...)
#
# Skor dalam TF-IDF digunakan untuk mengamati istilah-istilah berbeda yang mengandung informasi penting dalam dokumen tertentu. Untuk menerapkan TF-IDF dalam kode, gunakan fungsi TfidfVectorizer() dari library scikit-learn. TfidfVectorizer akan melakukan proses tokenisasi pada teks, mempelajari kosa kata, melakukan pembobotan frekuensi dokumen secara terbalik (inverse), dan memungkinkan Anda untuk melakukan proses encoding teks baru.
